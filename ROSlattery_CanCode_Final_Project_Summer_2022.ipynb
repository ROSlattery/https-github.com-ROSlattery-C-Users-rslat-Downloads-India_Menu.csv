# %%
#1st
import pandas as pd
India_Menu = pd.read_csv("https://raw.githubusercontent.com/ROSlattery/https-github.com-ROSlattery-C-Users-rslat-Downloads-India_Menu.csv/main/India_Menu%20(1).csv")
print(India_Menu)
# Out:
#        Menu Category              Menu Items Per Serve Size  Energy (kCal)  \
# 0       Regular Menu        McVeggie™ Burger          168 g         402.05
# 1       Regular Menu    McAloo Tikki Burger®          146 g         339.52
# 2       Regular Menu  McSpicy™ Paneer Burger          199 g         652.76
# 3       Regular Menu       Spicy Paneer Wrap          250 g         674.68
# 4       Regular Menu     American Veg Burger          177 g         512.17
# ..               ...                     ...            ...            ...
# 136  Condiments Menu  Tomato Ketchup Sachets            8 g          11.23
# 137  Condiments Menu             Maple Syrup           30 g          86.40
# 138  Condiments Menu            Cheese Slice           14 g          51.03
# 139  Condiments Menu              Sweet Corn           40 g          45.08
# 140  Condiments Menu    Mixed Fruit Beverage         180 ml          72.25
#
#      Protein (g)  Total fat (g)  Sat Fat (g)  Trans fat (g)  \
# ...

# %%
#2nd
import pandas as pd
India_Menu = pd.read_csv("https://raw.githubusercontent.com/ROSlattery/https-github.com-ROSlattery-C-Users-rslat-Downloads-India_Menu.csv/main/India_Menu%20(1).csv")
print(India_Menu.columns)
# Out:
# Index(['Menu Category', 'Menu Items', 'Per Serve Size', 'Energy (kCal)',
#        'Protein (g)', 'Total fat (g)', 'Sat Fat (g)', 'Trans fat (g)',
#        'Cholesterols (mg)', 'Total carbohydrate (g)', 'Total Sugars (g)',
#        'Added Sugars (g)', 'Sodium (mg)'],
#       dtype='object')

# %%
#3rd
import pandas as pd
from matplotlib import pyplot as plt
fig, axs = plt.subplots()
India_Menu = pd.read_csv("https://raw.githubusercontent.com/ROSlattery/https-github.com-ROSlattery-C-Users-rslat-Downloads-India_Menu.csv/main/India_Menu%20(1).csv")

vals = India_Menu['Total fat (g)'].value_counts()
print(vals)
# Out:
# 0.00     16
# 0.28      3
# 14.02     3
# 0.46      3
# 0.33      3
#          ..
# 15.46     1
# 17.28     1
# 2.00      1
# 13.55     1
# 0.02      1
# Name: Total fat (g), Length: 111, dtype: int64

# %%
#4th
import matplotlib.pyplot as plt
import pandas as pd

fig, axs = plt.subplots()
India_Menu = pd.read_csv("https://raw.githubusercontent.com/ROSlattery/https-github.com-ROSlattery-C-Users-rslat-Downloads-India_Menu.csv/main/India_Menu%20(1).csv")

    
India_Menu.head()
# Out:
#   Menu Category              Menu Items Per Serve Size  Energy (kCal)  \
# 0  Regular Menu        McVeggie™ Burger          168 g         402.05
# 1  Regular Menu    McAloo Tikki Burger®          146 g         339.52
# 2  Regular Menu  McSpicy™ Paneer Burger          199 g         652.76
# 3  Regular Menu       Spicy Paneer Wrap          250 g         674.68
# 4  Regular Menu     American Veg Burger          177 g         512.17
#
#    Protein (g)  Total fat (g)  Sat Fat (g)  Trans fat (g)  Cholesterols (mg)  \
# 0        10.24          13.83         5.34           0.16               2.49
# 1         8.50          11.31         4.27           0.20               1.47
# 2        20.29          39.45        17.12           0.18              21.85
# 3        20.96          39.10        19.73           0.26              40.93
# 4        15.30          23.45        10.51           0.17              25.24
#
#    Total carbohydrate (g)  Total Sugars (g)  Added Sugars (g)  Sodium (mg)
# ...

# %%
#5th
import matplotlib.pyplot as plt
import pandas as pd

fig, axs = plt.subplots()
India_Menu = pd.read_csv("https://raw.githubusercontent.com/ROSlattery/https-github.com-ROSlattery-C-Users-rslat-Downloads-India_Menu.csv/main/India_Menu%20(1).csv")

#Delete 1st column
India_Menu.drop(India_Menu.columns[[0, ]], axis =1, inplace=True)
India_Menu.head()
# Out:
#                Menu Items Per Serve Size  Energy (kCal)  Protein (g)  \
# 0        McVeggie™ Burger          168 g         402.05        10.24
# 1    McAloo Tikki Burger®          146 g         339.52         8.50
# 2  McSpicy™ Paneer Burger          199 g         652.76        20.29
# 3       Spicy Paneer Wrap          250 g         674.68        20.96
# 4     American Veg Burger          177 g         512.17        15.30
#
#    Total fat (g)  Sat Fat (g)  Trans fat (g)  Cholesterols (mg)  \
# 0          13.83         5.34           0.16               2.49
# 1          11.31         4.27           0.20               1.47
# 2          39.45        17.12           0.18              21.85
# 3          39.10        19.73           0.26              40.93
# 4          23.45        10.51           0.17              25.24
#
#    Total carbohydrate (g)  Total Sugars (g)  Added Sugars (g)  Sodium (mg)
# 0                   56.54              7.90              4.49       706.13
# ...

# %%
# 6th 
import matplotlib.pyplot as plt
import pandas as pd

fig, axs = plt.subplots()
India_Menu = pd.read_csv("https://raw.githubusercontent.com/ROSlattery/https-github.com-ROSlattery-C-Users-rslat-Downloads-India_Menu.csv/main/India_Menu%20(1).csv")
  
# Initialize the lists for X and Y
India_Menu = pd.DataFrame(India_Menu)
    
# Plot the data using bar() method of only TOTAL FAT
axs.bar(India_Menu['Menu Items'], India_Menu['Total fat (g)'], color='green')
axs.set_title("Menu Items")

axs.set_xlabel("Menu Items")
axs.tick_params(axis = 'x', labelrotation = 90)
axs.set_ylabel('Total fat (g)')

# Show the plot
plt.show()

# %%
#7th Graph the first 3 Burgers for comparison for Total Fat/easier to view data for analysis
import matplotlib.pyplot as plt
import pandas as pd

fig, axs = plt.subplots()
India_Menu = pd.read_csv("https://raw.githubusercontent.com/ROSlattery/https-github.com-ROSlattery-C-Users-rslat-Downloads-India_Menu.csv/main/India_Menu%20(1).csv")
  

India_Menu_de = India_Menu.iloc[0:3]    
print(India_Menu_de)
# Plot the data using bar() method
axs.bar(India_Menu_de['Menu Items'], India_Menu_de['Total fat (g)'], color='green')
axs.set_title("Burger Fat Content Comparison")

axs.set_xlabel("Menu Items")
axs.tick_params(axis = 'x', labelrotation = 90)
axs.set_ylabel('Total fat (g)')

# Show the plot
plt.show()
# Out:
#   Menu Category              Menu Items Per Serve Size  Energy (kCal)  \
# 0  Regular Menu        McVeggie™ Burger          168 g         402.05
# 1  Regular Menu    McAloo Tikki Burger®          146 g         339.52
# 2  Regular Menu  McSpicy™ Paneer Burger          199 g         652.76
#
#    Protein (g)  Total fat (g)  Sat Fat (g)  Trans fat (g)  Cholesterols (mg)  \
# 0        10.24          13.83         5.34           0.16               2.49
# 1         8.50          11.31         4.27           0.20               1.47
# 2        20.29          39.45        17.12           0.18              21.85
#
#    Total carbohydrate (g)  Total Sugars (g)  Added Sugars (g)  Sodium (mg)
# 0                   56.54              7.90              4.49       706.13
# 1                   50.27              7.05              4.07       545.34
# 2                   52.33              8.35              5.27      1074.58

# %%
#8th 
import matplotlib.pyplot as plt
import pandas as pd

fig, axs = plt.subplots()
India_Menu = pd.read_csv("https://raw.githubusercontent.com/ROSlattery/https-github.com-ROSlattery-C-Users-rslat-Downloads-India_Menu.csv/main/India_Menu%20(1).csv")
  
#try and only print fist 3 Burgers to compare

India_Menu_de = India_Menu.iloc[0:3]    
print(India_Menu_de)
# Plot the data to compare fat/protein ratio using bar() method
axs.bar(India_Menu_de['Menu Items'], India_Menu_de['Total fat (g)'], color='green')
axs.bar(India_Menu_de['Menu Items'], India_Menu_de['Protein (g)'], color='yellow')

axs.set_title("Carbohydrate to Protein Ratio")

axs.set_xlabel("Menu Items")
axs.tick_params(axis = 'x', labelrotation = 90)
axs.set_ylabel('grams')

# Show the plot
plt.show()
# Out:
#   Menu Category              Menu Items Per Serve Size  Energy (kCal)  \
# 0  Regular Menu        McVeggie™ Burger          168 g         402.05
# 1  Regular Menu    McAloo Tikki Burger®          146 g         339.52
# 2  Regular Menu  McSpicy™ Paneer Burger          199 g         652.76
#
#    Protein (g)  Total fat (g)  Sat Fat (g)  Trans fat (g)  Cholesterols (mg)  \
# 0        10.24          13.83         5.34           0.16               2.49
# 1         8.50          11.31         4.27           0.20               1.47
# 2        20.29          39.45        17.12           0.18              21.85
#
#    Total carbohydrate (g)  Total Sugars (g)  Added Sugars (g)  Sodium (mg)
# 0                   56.54              7.90              4.49       706.13
# 1                   50.27              7.05              4.07       545.34
# 2                   52.33              8.35              5.27      1074.58

# %%
#9th Bar Graphs to Compare 3 Burgers: Fat, Protein, Carbs, Sugar
import matplotlib.pyplot as plt
import pandas as pd

fig, axs = plt.subplots()
India_Menu = pd.read_csv("https://raw.githubusercontent.com/ROSlattery/https-github.com-ROSlattery-C-Users-rslat-Downloads-India_Menu.csv/main/India_Menu%20(1).csv")
  


India_Menu_de = India_Menu.iloc[0:3]    
print(India_Menu_de)
# Plot the data using bar() method
axs.bar(India_Menu_de['Menu Items'], India_Menu_de['Total fat (g)'], color='green')


axs.set_title("Burger Comparisons")

axs.set_xlabel("Menu Items")
axs.tick_params(axis = 'x', labelrotation = 90)
axs.set_ylabel('Total fat (g)')

plt.show()

#2nd graph
fig, axs = plt.subplots()
India_Menu = pd.read_csv("https://raw.githubusercontent.com/ROSlattery/https-github.com-ROSlattery-C-Users-rslat-Downloads-India_Menu.csv/main/India_Menu%20(1).csv")
  
axs.bar(India_Menu_de['Menu Items'], India_Menu_de['Protein (g)'], color='yellow')

axs.set_title("Burger Comparisions")

axs.set_xlabel("Menu Items")
axs.tick_params(axis = 'x', labelrotation = 90)
axs.set_ylabel('Protein(g)')

plt.show()
#graph3
fig, axs = plt.subplots()
India_Menu = pd.read_csv("https://raw.githubusercontent.com/ROSlattery/https-github.com-ROSlattery-C-Users-rslat-Downloads-India_Menu.csv/main/India_Menu%20(1).csv")
  
axs.bar(India_Menu_de['Menu Items'], India_Menu_de['Total carbohydrate (g)'], color='orange')

axs.set_title("Burger Comparisons")

axs.set_xlabel("Menu Items")
axs.tick_params(axis = 'x', labelrotation = 90)
axs.set_ylabel('Carboghydrates (g)')

plt.show()
#graph4
fig, axs = plt.subplots()
India_Menu = pd.read_csv("https://raw.githubusercontent.com/ROSlattery/https-github.com-ROSlattery-C-Users-rslat-Downloads-India_Menu.csv/main/India_Menu%20(1).csv")
  
axs.bar(India_Menu_de['Menu Items'], India_Menu_de['Total carbohydrate (g)'], color='blue')

axs.set_title("Burger Comparisons")

axs.set_xlabel("Menu Items")
axs.tick_params(axis = 'x', labelrotation = 90)
axs.set_ylabel('Total Sugars (g)')

plt.show()
# Out:
#   Menu Category              Menu Items Per Serve Size  Energy (kCal)  \
# 0  Regular Menu        McVeggie™ Burger          168 g         402.05
# 1  Regular Menu    McAloo Tikki Burger®          146 g         339.52
# 2  Regular Menu  McSpicy™ Paneer Burger          199 g         652.76
#
#    Protein (g)  Total fat (g)  Sat Fat (g)  Trans fat (g)  Cholesterols (mg)  \
# 0        10.24          13.83         5.34           0.16               2.49
# 1         8.50          11.31         4.27           0.20               1.47
# 2        20.29          39.45        17.12           0.18              21.85
#
#    Total carbohydrate (g)  Total Sugars (g)  Added Sugars (g)  Sodium (mg)
# 0                   56.54              7.90              4.49       706.13
# 1                   50.27              7.05              4.07       545.34
# 2                   52.33              8.35              5.27      1074.58

# %%
#10th can I put graphs next to eachother for easier comparison visually?

# %%
#10Side by side?
import matplotlib.pyplot as plt
import pandas as pd

fig = plt.figure(figsize = [20,5])
axs = fig.add_subplot(1,4,1)
India_Menu = pd.read_csv("https://raw.githubusercontent.com/ROSlattery/https-github.com-ROSlattery-C-Users-rslat-Downloads-India_Menu.csv/main/India_Menu%20(1).csv")
  


India_Menu_de = India_Menu.iloc[0:3]    
print(India_Menu_de)
# Plot the data using bar() method
axs.bar(India_Menu_de['Menu Items'], India_Menu_de['Total fat (g)'], color='green')


axs.set_title("Burger Comparisons")

axs.set_xlabel("Menu Items")
axs.tick_params(axis = 'x', labelrotation = 90)
axs.set_ylabel('Total fat (g)')



#2nd graph
axs = fig.add_subplot(1,4,2)
India_Menu = pd.read_csv("https://raw.githubusercontent.com/ROSlattery/https-github.com-ROSlattery-C-Users-rslat-Downloads-India_Menu.csv/main/India_Menu%20(1).csv")
  
axs.bar(India_Menu_de['Menu Items'], India_Menu_de['Protein (g)'], color='yellow')

axs.set_title("Burger Comparisions")

axs.set_xlabel("Menu Items")
axs.tick_params(axis = 'x', labelrotation = 90)
axs.set_ylabel('Protein(g)')


#graph3
axs = fig.add_subplot(1,4,3)
India_Menu = pd.read_csv("https://raw.githubusercontent.com/ROSlattery/https-github.com-ROSlattery-C-Users-rslat-Downloads-India_Menu.csv/main/India_Menu%20(1).csv")
  
axs.bar(India_Menu_de['Menu Items'], India_Menu_de['Total carbohydrate (g)'], color='orange')

axs.set_title("Burger Comparisons")

axs.set_xlabel("Menu Items")
axs.tick_params(axis = 'x', labelrotation = 90)
axs.set_ylabel('Carboghydrates (g)')


#graph4
axs = fig.add_subplot(1,4,4)
India_Menu = pd.read_csv("https://raw.githubusercontent.com/ROSlattery/https-github.com-ROSlattery-C-Users-rslat-Downloads-India_Menu.csv/main/India_Menu%20(1).csv")
  
axs.bar(India_Menu_de['Menu Items'], India_Menu_de['Total carbohydrate (g)'], color='blue')

axs.set_title("Burger Comparisons")

axs.set_xlabel("Menu Items")
axs.tick_params(axis = 'x', labelrotation = 90)
axs.set_ylabel('Total Sugars (g)')
# Out:
#   Menu Category              Menu Items Per Serve Size  Energy (kCal)  \
# 0  Regular Menu        McVeggie™ Burger          168 g         402.05
# 1  Regular Menu    McAloo Tikki Burger®          146 g         339.52
# 2  Regular Menu  McSpicy™ Paneer Burger          199 g         652.76
#
#    Protein (g)  Total fat (g)  Sat Fat (g)  Trans fat (g)  Cholesterols (mg)  \
# 0        10.24          13.83         5.34           0.16               2.49
# 1         8.50          11.31         4.27           0.20               1.47
# 2        20.29          39.45        17.12           0.18              21.85
#
#    Total carbohydrate (g)  Total Sugars (g)  Added Sugars (g)  Sodium (mg)
# 0                   56.54              7.90              4.49       706.13
# 1                   50.27              7.05              4.07       545.34
# 2                   52.33              8.35              5.27      1074.58
# Text(0, 0.5, 'Total Sugars (g)')

# %%
#11th Pie graph of manually entered 'size'
import matplotlib.pyplot as plt
import pandas as pd

fig, axs = plt.subplots()
India_Menu = pd.read_csv("https://raw.githubusercontent.com/ROSlattery/https-github.com-ROSlattery-C-Users-rslat-Downloads-India_Menu.csv/main/India_Menu%20(1).csv")


labels= ['Total fat (g)', 'Protien (g)', 'Total carbohydrate (g)', 'Total Sugars (g)']

colors=['blue', 'yellow', 'green', 'orange']

#problem is I typed in the numbers ***how to get it auto from Index?

sizes= [39.10, 20.96, 59.27, 3.50]

plt.title('Spicy Paneer Wrap')
plt.pie(sizes,labels=labels, colors=colors, startangle=90, autopct='%1.1f%%')

plt.axis('equal')

plt.show()

# %%
#12th Isolated the data from 'Spicy Paneer Wrap'
import matplotlib.pyplot as plt
import pandas as pd

India_Menu = pd.read_csv("https://raw.githubusercontent.com/ROSlattery/https-github.com-ROSlattery-C-Users-rslat-Downloads-India_Menu.csv/main/India_Menu%20(1).csv")

India_Menu_pie = India_Menu[['Total fat (g)', 'Protein (g)', 'Total carbohydrate (g)', 'Total Sugars (g)', 'Menu Items']]
India_Menu_pie.set_index('Menu Items', inplace = True)
print(India_Menu_pie.loc['Spicy Paneer Wrap'])

#Getting only the Columns from menu to plot
# Out:
# Total fat (g)             39.10
# Protein (g)               20.96
# Total carbohydrate (g)    59.27
# Total Sugars (g)           3.50
# Name: Spicy Paneer Wrap, dtype: float64

# %%
#13th Believed this to be working from the data...
import matplotlib.pyplot as plt
import pandas as pd

India_Menu = pd.read_csv("https://raw.githubusercontent.com/ROSlattery/https-github.com-ROSlattery-C-Users-rslat-Downloads-India_Menu.csv/main/India_Menu%20(1).csv")

India_Menu_pie = India_Menu[['Total fat (g)', 'Protein (g)', 'Total carbohydrate (g)', 'Total Sugars (g)', 'Menu Items']]
India_Menu_pie.set_index('Menu Items', inplace = True)
print(India_Menu_pie.loc['Spicy Paneer Wrap'])

labels= ['Total fat (g)', 'Protien (g)', 'Total carbohydrate (g)', 'Total Sugars (g)']

colors=['blue', 'yellow', 'green', 'orange']

plt.title('Spicy Paneer Wrap')
plt.pie(India_Menu_pie.loc["Spicy Paneer Wrap"],labels=India_Menu_pie.loc["Spicy Paneer Wrap"].index, colors=colors, startangle=90, autopct='%1.1f%%')



plt.show()
# Out:
# Total fat (g)             39.10
# Protein (g)               20.96
# Total carbohydrate (g)    59.27
# Total Sugars (g)           3.50
# Name: Spicy Paneer Wrap, dtype: float64

# %%
#14th NOT WORKING NOT UNIVERSAL
import matplotlib.pyplot as plt
import pandas as pd

India_Menu = pd.read_csv("https://raw.githubusercontent.com/ROSlattery/https-github.com-ROSlattery-C-Users-rslat-Downloads-India_Menu.csv/main/India_Menu%20(1).csv")

India_Menu_pie = India_Menu[['Total fat (g)', 'Protein (g)', 'Total carbohydrate (g)', 'Total Sugars (g)', 'Menu Items']]
India_Menu_pie.set_index('Menu Items', inplace = True)
print(India_Menu_pie.loc['McSpicy™ Paneer Burger'])

labels= ['Total fat (g)', 'Protien (g)', 'Total carbohydrate (g)', 'Total Sugars (g)']

colors=['blue', 'yellow', 'green', 'orange']
plt.title('McSpicy™ Paneer Burger')
plt.pie(India_Menu_pie.loc['McSpicy™ Paneer Burger'],labels=India_Menu_pie.loc['McSpicy™ Paneer Burger'].index, colors=colors, startangle=90, autopct='%1.1f%%')



plt.show()
# Out:
# Total fat (g)             39.45
# Protein (g)               20.29
# Total carbohydrate (g)    52.33
# Total Sugars (g)           8.35
# Name: McSpicy™ Paneer Burger, dtype: float64
